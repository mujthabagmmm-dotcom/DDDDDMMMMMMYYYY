# %% [markdown]
# <a href="https://colab.research.google.com/github/mujthabagmmm-dotcom/DDDDDMMMMMMYYYY/blob/main/Copy_of_Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10

# %%
#list operation
list=[1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]
